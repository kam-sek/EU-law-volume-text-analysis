# %%
import os 
import regex as re
from bs4 import BeautifulSoup
import PyPDF2
import pandas as pd
from collections import Counter
import logging
import time

# Load a webscrapped dataset
data = pd.read_csv('../Data/proposals_processed.csv')

# Define the folder containing the regulation documents
doc_folder = os.path.abspath(os.path.join(os.getcwd(),'..', 'Data', 'Regulations'))

# %%
def extract_section_from_text(text, start_pattern, end_pattern=None, include_start_pattern=True, include_end_pattern=False, exclude_cod=False, case_sensitive=True):
    # Compile the start and end patterns based on case sensitivity switch
    def compile_pattern(pattern, case_sensitive):
        if not case_sensitive:
            return re.compile(pattern, re.IGNORECASE)
        return re.compile(pattern)

    # Compile the start pattern with or without case sensitivity
    start_regex = compile_pattern(start_pattern, case_sensitive)
    start_match = start_regex.search(text)
    if not start_match:
        return ""
    
    start_index = start_match.start() if include_start_pattern else start_match.end()
    
    if end_pattern:
        # Compile the end pattern with or without case sensitivity
        end_regex = compile_pattern(end_pattern, case_sensitive)
        end_match = end_regex.search(text[start_index:])
        if end_match:
            end_index = end_match.end() + start_index if include_end_pattern else end_match.start() + start_index
        else:
            end_index = len(text)  # End at EOF if the end pattern isn't found
    else:
        end_index = len(text)
    
    section_text = text[start_index:end_index].strip()
    
    # Subtract 11 characters (brackets + 9 digits) from the end of Explanatory Memorandum
    if exclude_cod and len(section_text) > 11:
        section_text = section_text[:-11]

    return section_text

# %%
# Function to process PDF files
def process_pdf(file_path):
    with open(file_path, 'rb') as pdf_file:
        reader = PyPDF2.PdfReader(pdf_file)
        text = ""
        for page in reader.pages:
            text += page.extract_text()
    return text

# %%
# Function to count words
def word_count(text):
    text = text.replace('\u00A0', ' ')
    words = re.findall(r'\b\w+(?:-\w+)*\b', text)
    word_counts = Counter(words)
    return sum(word_counts.values())

# %%
def clean_metadata(text):

    # Define patterns for known metadata (adjust the patterns as needed)
    patterns = [
        r'docVars.*?\]',  # Remove docVars metadata
        r'DQCResult_[\w]+;?\s*\d+;\d+',  # Remove DQCResult related metadata
        r'\[\w+=.*?\]',  # Remove key-value metadata in brackets, e.g. [name=...]
        r'LW_[\w]+;?\s*\d+;\d+',  # Remove LW_ prefixed metadata
        r'DQCWithWarnings.*',  # Remove DQC warnings
        r'DocumentContent.*',  # Remove document content markers
        r'@\w+',  # Remove any usernames or email references (if applicable)
        r'[^\x00-\x7F]',  # Remove non-ASCII characters (including Õ)
    ]

    # Iterate over the patterns and remove them from the text
    for pattern in patterns:
        text = re.sub(pattern, '', text, flags=re.DOTALL)

    # Clean up extra spaces left after removal of metadata
    text = re.sub(r'\s+', ' ', text).strip()
    
    return text

# %%
def process_celex(celex_number, doc_folder, start_chars=100, end_chars=100):
    pdf_file = os.path.join(doc_folder, f"{celex_number}.pdf")
    annex_pdf_file = os.path.join(doc_folder, f"{celex_number}_annex.pdf")  # Adjust annex filename pattern
    html_file = os.path.join(doc_folder, f"{celex_number}.html")

    sections = {}

    # Handling different file types
    if os.path.exists(html_file):
        print(f"Processing HTML file for CELEX {celex_number}")  # Debugging print
        with open(html_file, 'r', encoding='utf-8') as file:
            soup = BeautifulSoup(file, 'html.parser')

        # Extract the raw text from the HTML document
        text = soup.get_text(separator=' ', strip=True)

        # Clean the metadata from the raw text
        cleaned_text = clean_metadata(text)

        # First check for the presence of 'LEGISLATIVE FINANCIAL STATEMENT' and 'ANNEXES'
        has_financial_statement = 'LEGISLATIVE FINANCIAL STATEMENT' in cleaned_text

        # Search for ANNEXES first, and only if not found, search for ANNEX
        has_annexes = re.search(r'ANNEXES', cleaned_text)
        if has_annexes:
            annexes_start_pattern = 'ANNEXES'
        else:
            has_annexes = re.search(r'ANNEX', cleaned_text)
            if has_annexes:
                annexes_start_pattern = 'ANNEX'

        # Extract preamble
        preamble_start_regex = r'THE EUROPEAN PARLIAMENT AND THE COUNCIL|THE COUNCIL OF THE EUROPEAN UNION'
        preamble_end_regex = r'HAVE ADOPTED|HAS DECIDED|HAVE DECIDED|HAS ADOPTED|HAVE ADOPED|HEREBY RECOMMEND|HA VE ADOPTED|HEREBY INVITE|RECOMMEND that the Member States'
        preamble = extract_section_from_text(cleaned_text, preamble_start_regex, preamble_end_regex)

        # Extract explanatory memorandum
        explanatory_memorandum = extract_section_from_text(cleaned_text, 'EXPLANATORY MEMORANDUM', preamble_start_regex, exclude_cod=True, case_sensitive=False)

        # Adjust the end of articles section based on the presence of financial statement or annexes
        if has_financial_statement:
            articles_end = 'LEGISLATIVE FINANCIAL STATEMENT'
        elif has_annexes:
            articles_end = annexes_start_pattern
        else:
            articles_end = None  # No specific end, capture till the end of the document

        # Extract articles
        articles = extract_section_from_text(cleaned_text, preamble_end_regex, articles_end)

        # Extract financial statement if present
        financial_statement = ""
        if has_financial_statement:
            financial_statement = extract_section_from_text(cleaned_text, 'LEGISLATIVE FINANCIAL STATEMENT', 'ANNEXES', include_start_pattern=True, include_end_pattern=False)

        # Extract annexes if present
        annexes = ""
        if has_annexes:
            annexes = extract_section_from_text(cleaned_text, 'ANNEXES', None, include_start_pattern=True, include_end_pattern=False)

        # Update sections
        sections.update({
            'Explanatory_Memorandum_Word_Count': word_count(explanatory_memorandum),
            'Preamble_Word_Count': word_count(preamble),
            'Articles_Word_Count': word_count(articles),
            'Financial_Statement_Word_Count': word_count(financial_statement),
            'Annexes_Word_Count': word_count(annexes),
            'Explanatory_Memorandum_Text': explanatory_memorandum,
            'Preamble_Text': preamble,
            'Articles_Text': articles,
            'Financial_Statement_Text': financial_statement,
            'Annexes_Text': annexes
        })

     # Handling PDF files (including separate annex file)
    elif os.path.exists(pdf_file):

        print(f"Processing PDF file for CELEX {celex_number}")  # Debugging print
        text = process_pdf(pdf_file)

        # Clean the metadata from the raw text
        cleaned_text = clean_metadata(text)

        # First check for the presence of 'LEGISLATIVE FINANCIAL STATEMENT' and 'ANNEXES'
        has_financial_statement = 'LEGISLATIVE FINANCIAL STATEMENT' in cleaned_text

        # Initialize `has_annexes` to False at the start to avoid referencing before assignment
        has_annexes = False
        
        # If there is a separate annex file
        if os.path.exists(annex_pdf_file):
            # Extract legislative financial statement from the main file
            financial_statement = ""
            if has_financial_statement:
                financial_statement = extract_section_from_text(cleaned_text, 'LEGISLATIVE FINANCIAL STATEMENT', include_start_pattern=True, include_end_pattern=False)
            
            # End articles at the legislative financial statement if it exists
            articles_end = 'LEGISLATIVE FINANCIAL STATEMENT' if has_financial_statement else None
            preamble_start_regex = r'THE EUROPEAN PARLIAMENT AND THE COUNCIL|THE COUNCIL OF THE EUROPEAN UNION'
            preamble_end_regex = r'HAVE ADOPTED|HAS DECIDED|HAVE DECIDED|HAS ADOPTED|HAVE ADOPED|HEREBY RECOMMEND|HA VE ADOPTED|HEREBY INVITE|RECOMMEND that the Member States'
            preamble = extract_section_from_text(cleaned_text, preamble_start_regex, preamble_end_regex)

            explanatory_memorandum = extract_section_from_text(cleaned_text, 'EXPLANATORY MEMORANDUM', preamble_start_regex, exclude_cod=True, case_sensitive=False)
            articles = extract_section_from_text(cleaned_text, preamble_end_regex, articles_end)

            # Process annexes from the annex PDF file
            annexes = process_pdf(annex_pdf_file)

            # If there is no separate annex file
        else:
            # Check for ANNEXES or ANNEX in the main document
            if re.search(r'ANNEXES', cleaned_text):
                has_annexes = True
                annexes_start_pattern = 'ANNEXES'
            elif re.search(r'ANNEX', cleaned_text):
                has_annexes = True
                annexes_start_pattern = 'ANNEX'
            else:
                annexes_start_pattern = None

        # Extract preamble
        preamble_start_regex = r'THE EUROPEAN PARLIAMENT AND THE COUNCIL|THE COUNCIL OF THE EUROPEAN UNION'
        preamble_end_regex = r'HAVE ADOPTED|HAS DECIDED|HAVE DECIDED|HAS ADOPTED|HAVE ADOPED|HEREBY RECOMMEND|HA VE ADOPTED|HEREBY INVITE|RECOMMEND that the Member States'
        preamble = extract_section_from_text(cleaned_text, preamble_start_regex, preamble_end_regex)

        # Extract explanatory memorandum
        explanatory_memorandum = extract_section_from_text(cleaned_text, 'EXPLANATORY MEMORANDUM', preamble_start_regex, exclude_cod=True, case_sensitive=False)

        # Adjust the end of articles section based on the presence of financial statement or annexes
        if has_financial_statement:
            articles_end = 'LEGISLATIVE FINANCIAL STATEMENT'
        elif has_annexes:
            articles_end = annexes_start_pattern
        else:
            articles_end = None  # No specific end, capture till the end of the document

        # Extract articles
        articles = extract_section_from_text(cleaned_text, preamble_end_regex, articles_end)

        # Extract financial statement if present
        financial_statement = ""
        if has_financial_statement:
            financial_statement = extract_section_from_text(cleaned_text, 'LEGISLATIVE FINANCIAL STATEMENT', 'ANNEXES', include_start_pattern=True, include_end_pattern=False)

        # Extract annexes from the main document
        annexes = ""
        if has_annexes:
            annexes = extract_section_from_text(cleaned_text, annexes_start_pattern, None)
            
        # Update sections
        sections.update({
            'Explanatory_Memorandum_Word_Count': word_count(explanatory_memorandum),
            'Preamble_Word_Count': word_count(preamble),
            'Articles_Word_Count': word_count(articles),
            'Financial_Statement_Word_Count': word_count(financial_statement),
            'Annexes_Word_Count': word_count(annexes),
            'Explanatory_Memorandum_Text': explanatory_memorandum,
            'Preamble_Text': preamble,
            'Articles_Text': articles,
            'Financial_Statement_Text': financial_statement,
            'Annexes_Text': annexes
        })

    else:
        print(f"No valid document format found for CELEX {celex_number}")
        return None

    # Modify the output to return the specified number of characters for each section
    for section_key in ['Explanatory_Memorandum_Text', 'Preamble_Text', 'Articles_Text', 'Financial_Statement_Text', 'Annexes_Text']:
        section_text = sections.get(section_key, "")
        if len(section_text) > (start_chars + end_chars):
            sections[section_key] = section_text[:start_chars] + '...' + section_text[-end_chars:]
        else:
            sections[section_key] = section_text  # If the text is shorter, return it as is

    sections['Total_Word_Count'] = sum([sections.get('Explanatory_Memorandum_Word_Count', 0),
                                        sections.get('Preamble_Word_Count', 0),
                                        sections.get('Articles_Word_Count', 0),
                                        sections.get('Financial_Statement_Word_Count', 0),
                                        sections.get('Annexes_Word_Count', 0)])

    return sections

# %%
def apply_to_dataframe(data, doc_folder):
    results = []
    total_records = len(data)  

    # Loop through each CELEX number in the DataFrame
    for celex in data['CELEX'][:total_records]:
        try:
            # Initialize a dictionary to hold the results for each CELEX number
            row_result = {}

            # Add the original CELEX and any other columns from the input DataFrame
            row_result['CELEX'] = celex

            # Process the CELEX document based on its available formats
            if os.path.exists(os.path.join(doc_folder, f"{celex}.html")):
                sections = process_celex(celex, doc_folder)
                row_result['Format_Used'] = 'html'
            elif os.path.exists(os.path.join(doc_folder, f"{celex}.pdf")):
                sections = process_celex(celex, doc_folder)
                row_result['Format_Used'] = 'pdf'
            else:
                sections = None
                row_result['Format_Used'] = 'none'
                row_result['Error'] = 'No valid format found'
                logging.warning(f"Failed to process CELEX {celex} due to {row_result['Error']}")
                results.append(row_result)
                continue  # Skip to the next CELEX if no valid document is found

            # If sections were successfully extracted, append the results
            if sections:
                row_result.update(sections)  # Merge the sections dictionary into the row_result
                logging.info(f"Successfully processed CELEX {celex} as {row_result['Format_Used']}")
            else:
                # If sections couldn't be processed, log the failure
                row_result['Total_Word_Count'] = None
                row_result['Explanatory_Memorandum_Word_Count'] = None
                row_result['Preamble_Word_Count'] = None
                row_result['Articles_Word_Count'] = None
                row_result['Annexes_Word_Count'] = None
                row_result['Explanatory_Memorandum_Text'] = ''
                row_result['Preamble_Text'] = ''
                row_result['Articles_Text'] = ''
                row_result['Annexes_Text'] = ''
                logging.warning(f"Sections not found for CELEX {celex}")

            results.append(row_result)

        except Exception as e:
            logging.error(f"Error processing CELEX {celex}: {e}")
            row_result['Error'] = str(e)
            results.append(row_result)
            continue  # Continue processing the next CELEX even if an error occurs

    # Convert the list of results into a DataFrame
    results_df = pd.DataFrame(results)

    # Concatenate the original data with the new results (using CELEX as the key)
    final_data = pd.concat([data.set_index('CELEX'), results_df.set_index('CELEX')], axis=1).reset_index()

    return final_data

# %%
#Test 
process_celex("52000PC0126", doc_folder, start_chars= 1000, end_chars= 1000)
# Out:
# Processing HTML file for CELEX 52000PC0126
# {'Explanatory_Memorandum_Word_Count': 616,
#  'Preamble_Word_Count': 2740,
#  'Articles_Word_Count': 0,
#  'Financial_Statement_Word_Count': 0,
#  'Annexes_Word_Count': 0,
#  'Explanatory_Memorandum_Text': 'EXPLANATORY MEMORANDUM 1. In the context of a people\'s Europe, the Commission attaches great importance to simplifying and clarifying Community law so as to make it clearer and more accessible to the ordinary citizen, thus giving him new opportunities and the chance to make use of the specific rights it gives him. This aim cannot be achieved so long as numerous provisions that have been amended several times, often quite substantially, remain scattered, so that they must be sought partly in the original instrument and partly in later amending ones. Considerable research work, comparing many different instruments, is thus needed to identify the current rules. For this reason a codification of rules that have frequently been amended is also essential if Community law is to be clear and transparent. 2. On 1 April 1987 the Commission therefore decided to instruct its staff that all legislative measures should be codified after no more than ten amendments, stressing that this was a minimum ...together with only such formal amendments as are required by the codification exercise itself. [1] Entered in the legislative programme for 1995. [2] See Annex II, Part A, of this proposal. This legislative codification proposal also reflects the replacement of references to the "ECU" with references to the "euro", as laid down by Council Regulation (EC) No 1103/97 of 19 June 1997 [3]. [3] OJ L 162, 19.6.1997, p. 1. 5. This legislative codification proposal was drawn up on the basis of the texts of the acts published in the Official Journal, in all the official languages. Although the articles have been given new numbers, the old numbering has been retained in the margin for ease of reference; the correlation between the old and new numbers is shown in a table set out in Annex III, to the codified Directive. Proposal for a DIRECTIVE OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL on the admission of securities to official stock exchange listing and on information to be published on those',
#  'Preamble_Text': 'THE EUROPEAN PARLIAMENT AND THE COUNCIL OF THE EUROPEAN UNION, Having regard to the Treaty establishing the European Economic Community, and in particular Articles 44 and 95 thereof, Having regard to the proposal from the Commission, Having regard to the opinion of the Economic and Social Committee [4], [4] OJ C Acting in accordance with the procedure laid down in Article 251 of the Treaty [5], [5] OJ C Whereas: &gt;TABLE POSITION&gt; &gt;TABLE POSITION&gt; &gt;TABLE POSITION&gt; &gt;TABLE POSITION&gt; &gt;TABLE POSITION&gt; &gt;TABLE POSITION&gt; &gt;TABLE POSITION&gt; TABLE OF CONTENTS RECITALS TITLE I DEFINITIONS AND SCOPE OF APPLICATION Chapter I Definitions Article 1 Chapter II Scope of application Article 2 Article 3 Article 4 TITLE II GENERAL PROVISIONS CONCERNING THE OFFICIAL LISTING OF SECURITIES Chapter I General conditions for admission Article 5 Article 6 Article 7 Chapter II More stringent or additional conditions and obligations Article 8 Chapter III Derogations Article 9...e simultaneously Directives 79/279/EEC and 80/390/EEC. [7] 30.6.1983 for the Member States which introduce simultaneously Directives 79/279/EEC, 80/390/EEC and 82/121/EEC. 80/390/EEC // 19 September 198211 82/121/EEC // 30 June 1983 [8] [8] Time-limit for application:30.6.1986. 82/148/EEC // 87/345/EEC // 1 January 1990 1 January 1991 for Spain 1 January 1992 for Portugal 88/627/EEC // 1 January 1991 90/211/EEC // 17 April 1991 94/18/EC // ANNEX III CORRELATION TABLE &gt;TABLE POSITION&gt; &gt;TABLE POSITION&gt; &gt;TABLE POSITION&gt; &gt;TABLE POSITION&gt; &gt;TABLE POSITION&gt; &gt;TABLE POSITION&gt; &gt;TABLE POSITION&gt; &gt;TABLE POSITION&gt; &gt;TABLE POSITION&gt; &gt;TABLE POSITION&gt; &gt;TABLE POSITION&gt; &gt;TABLE POSITION&gt; &gt;TABLE POSITION&gt; &gt;TABLE POSITION&gt; &gt;TABLE POSITION&gt; &gt;TABLE POSITION&gt; &gt;TABLE POSITION&gt; &gt;TABLE POSITION&gt; &gt;TABLE POSITION&gt; &gt;TABLE POSITION&gt; &gt;TABLE POSITION&gt; &gt;TABLE POSITION&gt; &gt;TABLE POSITION&gt;',
#  'Articles_Text': '',
#  'Financial_Statement_Text': '',
#  'Annexes_Text': '',
#  'Total_Word_Count': 3356}

# %%
# Start timing
start_time = time.time()

# Apply the process and save the DataFrame to a CSV file
processed_data = apply_to_dataframe(data, doc_folder)

# Save the processed data to a CSV file
processed_data.to_csv('../Data/proposals_word_count_processed.csv', index=False)

# End timing
end_time = time.time()

elapsed_time_seconds = end_time - start_time
minutes = elapsed_time_seconds // 60  # Integer division to get full minutes
seconds = elapsed_time_seconds % 60    # Modulus to get the remainder in seconds

print(f"Elapsed time: {minutes} minutes and {seconds:.2f} seconds")
# Out:
# Processing HTML file for CELEX 52023PC0637
# Processing HTML file for CELEX 52023PC0636
# Processing HTML file for CELEX 52023PC0770
# Processing HTML file for CELEX 52023PC0769
# Processing HTML file for CELEX 52023PC0783
# Processing HTML file for CELEX 52023PC0779
# Processing HTML file for CELEX 52023PC0781
# Processing HTML file for CELEX 52023PC0771
# Processing HTML file for CELEX 52023PC0752
# Processing HTML file for CELEX 52023PC0905
# Processing HTML file for CELEX 52023PC0753
# Processing HTML file for CELEX 52023PC0777
# Processing HTML file for CELEX 52023PC0755
# Processing HTML file for CELEX 52023PC0754
# Processing HTML file for CELEX 52023PC0738
# Processing HTML file for CELEX 52023PC0728
# Processing HTML file for CELEX 52023PC0727
# Processing HTML file for CELEX 52023PC0733
# Processing HTML file for CELEX 52023PC0716
# Processing HTML file for CELEX 52023PC0692
# Processing HTML file for CELEX 52023PC0702
# Processing HTML file for CELEX 52023PC0698
# Processing HTML file for CELEX 52023PC0642
# Processing HTML file for CELEX 52023PC0661
# Processing HTML file for CELEX 52023PC0593
# Processing HTML file for CELEX 52023PC0649
# Processing HTML file for CELEX 52023PC0643
# Processing HTML file for CELEX 52023PC0647
# Processing HTML file for CELEX 52023PC0660
# Processing HTML file for CELEX 52023PC0639
# Processing HTML file for CELEX 52023PC0582
# Processing HTML file for CELEX 52023PC0584
# Processing HTML file for CELEX 52023PC0596
# Processing HTML file for CELEX 52023PC0591
# Processing HTML file for CELEX 52023PC0592
# Processing HTML file for CELEX 52023PC0645
# Processing HTML file for CELEX 52023PC0533
# Processing HTML file for CELEX 52023PC0512
# Processing HTML file for CELEX 52023PC0516
# Processing HTML file for CELEX 52023PC0515
# Processing HTML file for CELEX 52023PC0502
# Processing HTML file for CELEX 52023PC0462
# Processing HTML file for CELEX 52023PC0459
# Processing HTML file for CELEX 52023PC0395
# Processing HTML file for CELEX 52023PC0451
# Processing HTML file for CELEX 52023PC0445
# Processing HTML file for CELEX 52023PC0441
# Processing HTML file for CELEX 52023PC0443
# Processing HTML file for CELEX 52023PC0424
# Processing HTML file for CELEX 52023PC0402
# Processing HTML file for CELEX 52023PC0414
# Processing HTML file for CELEX 52023PC0411
# Processing HTML file for CELEX 52023PC0415
# Processing HTML file for CELEX 52023PC0416
# Processing HTML file for CELEX 52023PC0420
# Processing HTML file for CELEX 52023PC0348
# Processing HTML file for CELEX 52023PC0426
# Processing HTML file for CELEX 52023PC0367
# Processing HTML file for CELEX 52023PC0362
# Processing HTML file for CELEX 52023PC0366
# Processing HTML file for CELEX 52023PC0360
# Processing HTML file for CELEX 52023PC0368
# Processing HTML file for CELEX 52023PC0364
# Processing HTML file for CELEX 52023PC0369
# Processing HTML file for CELEX 52023PC0359
# Processing HTML file for CELEX 52023PC0338
# Processing HTML file for CELEX 52023PC0335
# Processing HTML file for CELEX 52023PC0328
# Processing HTML file for CELEX 52023PC0314
# Processing HTML file for CELEX 52023PC0280
# Processing HTML file for CELEX 52023PC0269
# Processing HTML file for CELEX 52023PC0270
# Processing HTML file for CELEX 52023PC0273
# Processing HTML file for CELEX 52023PC0272
# Processing HTML file for CELEX 52023PC0271
# Processing HTML file for CELEX 52023PC0279
# Processing HTML file for CELEX 52023PC0278
# Processing HTML file for CELEX 52023PC0256
# Processing HTML file for CELEX 52023PC0258
# Processing HTML file for CELEX 52023PC0244
# Processing HTML file for CELEX 52023PC0106
# Processing HTML file for CELEX 52023PC0189
# Processing HTML file for CELEX 52023PC0234
# Processing HTML file for CELEX 52023PC0237
# Processing HTML file for CELEX 52023PC0217
# Processing HTML file for CELEX 52023PC0240
# Processing HTML file for CELEX 52023PC0222
# Processing HTML file for CELEX 52023PC0224
# Processing HTML file for CELEX 52023PC0221
# Processing HTML file for CELEX 52023PC0232
# Processing HTML file for CELEX 52023PC0231
# Processing HTML file for CELEX 52023PC0223
# Processing HTML file for CELEX 52023PC0192
# Processing HTML file for CELEX 52023PC0193
# Processing HTML file for CELEX 52023PC0201
# Processing HTML file for CELEX 52023PC0228
# Processing HTML file for CELEX 52023PC0227
# Processing HTML file for CELEX 52023PC0226
# Processing HTML file for CELEX 52023PC0209
# Processing HTML file for CELEX 52023PC0208
# Processing HTML file for CELEX 52023PC0229
# Processing HTML file for CELEX 52023PC0194
# Processing HTML file for CELEX 52023PC0185
# Processing HTML file for CELEX 52023PC0178
# Processing HTML file for CELEX 52023PC0177
# Processing HTML file for CELEX 52023PC0166
# Processing HTML file for CELEX 52023PC0155
# Processing HTML file for CELEX 52023PC0161
# Processing HTML file for CELEX 52023PC0160
# Processing HTML file for CELEX 52023PC0148
# Processing HTML file for CELEX 52023PC0147
# Processing HTML file for CELEX 52023PC0108
# Processing HTML file for CELEX 52023PC0127
# Processing HTML file for CELEX 52023PC0128
# Processing HTML file for CELEX 52023PC0126
# Processing HTML file for CELEX 52023PC0124
# Processing HTML file for CELEX 52023PC0098
# Processing HTML file for CELEX 52023PC0122
# Processing HTML file for CELEX 52023PC0125
# Processing HTML file for CELEX 52023PC0094
# Processing HTML file for CELEX 52023PC0088
# Processing HTML file for CELEX 52023PC0071
# Processing HTML file for CELEX 52023PC0065
# Processing HTML file for CELEX 52023PC0063
# Processing HTML file for CELEX 52023PC0074
# Processing HTML file for CELEX 52023PC0053
# Processing HTML file for CELEX 52023PC0031
# Processing HTML file for CELEX 52023PC0010
# Processing HTML file for CELEX 52022PC0748
# Processing HTML file for CELEX 52022PC0732
# Processing HTML file for CELEX 52022PC0729
# Processing HTML file for CELEX 52022PC0731
# Processing HTML file for CELEX 52022PC0721
# Processing HTML file for CELEX 52022PC0697
# Processing HTML file for CELEX 52022PC0762
# Processing HTML file for CELEX 52022PC0698
# Processing HTML file for CELEX 52022PC0760
# Processing HTML file for CELEX 52022PC0761
# Processing HTML file for CELEX 52022PC0688
# Processing HTML file for CELEX 52022PC0702
# Processing HTML file for CELEX 52022PC0684
# Processing HTML file for CELEX 52022PC0677
# Processing HTML file for CELEX 52022PC0672
# Processing HTML file for CELEX 52022PC0659
# Processing HTML file for CELEX 52022PC0666
# Processing HTML file for CELEX 52022PC0667
# Processing HTML file for CELEX 52022PC0720
# Processing HTML file for CELEX 52022PC0586
# Processing HTML file for CELEX 52022PC0597
# Processing HTML file for CELEX 52022PC0596
# Processing HTML file for CELEX 52022PC0571
# Processing HTML file for CELEX 52022PC0563
# Processing HTML file for CELEX 52022PC0542
# Processing HTML file for CELEX 52022PC0540
# Processing HTML file for CELEX 52022PC0480
# Processing HTML file for CELEX 52022PC0541
# Processing HTML file for CELEX 52022PC0546
# Processing HTML file for CELEX 52022PC0526
# Processing HTML file for CELEX 52022PC0503
# Processing HTML file for CELEX 52022PC0496
# Processing HTML file for CELEX 52022PC0489
# Processing HTML file for CELEX 52022PC0495
# Processing HTML file for CELEX 52022PC0461
# Processing HTML file for CELEX 52022PC0459
# Processing HTML file for CELEX 52022PC0462
# Processing HTML file for CELEX 52022PC0465
# Processing HTML file for CELEX 52022PC0457
# Processing HTML file for CELEX 52022PC0454
# Processing HTML file for CELEX 52022PC0453
# Processing HTML file for CELEX 52022PC0557
# Processing HTML file for CELEX 52022PC0662
# Processing HTML file for CELEX 52022PC0381
# Processing HTML file for CELEX 52022PC0362
# Processing HTML file for CELEX 52022PC0349
# Processing HTML file for CELEX 52022PC0338
# Processing HTML file for CELEX 52022PC0334
# Processing HTML file for CELEX 52022PC0329
# Processing HTML file for CELEX 52022PC0450
# Processing HTML file for CELEX 52022PC0325
# Processing HTML file for CELEX 52022PC0304
# Processing HTML file for CELEX 52022PC0305
# Processing HTML file for CELEX 52022PC0296
# Processing HTML file for CELEX 52022PC0313
# Processing HTML file for CELEX 52022PC0288
# Processing HTML file for CELEX 52022PC0245
# Processing HTML file for CELEX 52022PC0242
# Processing HTML file for CELEX 52022PC0231
# Processing HTML file for CELEX 52022PC0222
# Processing HTML file for CELEX 52022PC0223
# Processing HTML file for CELEX 52022PC0209
# Processing HTML file for CELEX 52022PC0204
# Processing HTML file for CELEX 52022PC0197
# Processing HTML file for CELEX 52022PC0658
# Processing HTML file for CELEX 52022PC0650
# Processing HTML file for CELEX 52022PC0655
# Processing HTML file for CELEX 52022PC0177
# Processing HTML file for CELEX 52022PC0189
# Processing HTML file for CELEX 52022PC0195
# Processing HTML file for CELEX 52022PC0187
# Processing HTML file for CELEX 52022PC0184
# Processing HTML file for CELEX 52022PC0171
# Processing PDF file for CELEX 52022PC0174
# Processing HTML file for CELEX 52022PC0179
# Processing HTML file for CELEX 52022PC0150
# Processing HTML file for CELEX 52022PC0156
# Processing PDF file for CELEX 52022PC0151
# Processing HTML file for CELEX 52022PC0157
# Processing HTML file for CELEX 52022PC0142
# Processing HTML file for CELEX 52022PC0144
# Processing HTML file for CELEX 52022PC0143
# Processing HTML file for CELEX 52022PC0134
# Processing HTML file for CELEX 52022PC0145
# Processing HTML file for CELEX 52022PC0135
# Processing HTML file for CELEX 52022PC0122
# Processing HTML file for CELEX 52022PC0119
# Processing HTML file for CELEX 52022PC0113
# Processing HTML file for CELEX 52022PC0120
# Processing HTML file for CELEX 52022PC0089
# Processing HTML file for CELEX 52022PC0105
# Processing HTML file for CELEX 52022PC0112
# Processing HTML file for CELEX 52022PC0109
# Processing HTML file for CELEX 52022PC0076
# Processing HTML file for CELEX 52022PC0068
# Processing HTML file for CELEX 52022PC0071
# Processing HTML file for CELEX 52022PC0053
# Processing HTML file for CELEX 52022PC0051
# Processing HTML file for CELEX 52022PC0057
# Processing HTML file for CELEX 52022PC0046
# Processing HTML file for CELEX 52022PC0055
# Processing HTML file for CELEX 52022PC0050
# Processing HTML file for CELEX 52022PC0032
# Processing HTML file for CELEX 52022PC0037
# Processing HTML file for CELEX 52022PC0026
# Processing HTML file for CELEX 52022PC0009
# Processing HTML file for CELEX 52022PC0018
# Processing HTML file for CELEX 52022PC0004
# Processing HTML file for CELEX 52021PC0832
# Processing HTML file for CELEX 52021PC0998
# Processing HTML file for CELEX 52021PC0997
# Processing HTML file for CELEX 52021PC0891
# Processing HTML file for CELEX 52021PC0890
# Processing HTML file for CELEX 52021PC0805
# Processing HTML file for CELEX 52021PC0803
# Processing HTML file for CELEX 52021PC0804
# Processing HTML file for CELEX 52021PC0812
# Processing HTML file for CELEX 52021PC0813
# Processing HTML file for CELEX 52021PC0802
# Processing HTML file for CELEX 52021PC0851
# Processing HTML file for CELEX 52021PC0776
# Processing HTML file for CELEX 52021PC0775
# Processing HTML file for CELEX 52021PC0762
# Processing HTML file for CELEX 52021PC0782
# Processing HTML file for CELEX 52021PC0784
# Processing HTML file for CELEX 52021PC0769
# Processing HTML file for CELEX 52021PC0756
# Processing HTML file for CELEX 52021PC0760
# Processing HTML file for CELEX 52021PC0757
# Processing HTML file for CELEX 52021PC0759
# Processing HTML file for CELEX 52021PC0767
# Processing HTML file for CELEX 52021PC0726
# Processing HTML file for CELEX 52021PC0727
# Processing HTML file for CELEX 52021PC0724
# Processing HTML file for CELEX 52021PC0725
# Processing HTML file for CELEX 52021PC0722
# Processing HTML file for CELEX 52021PC0723
# Processing HTML file for CELEX 52021PC0734
# Processing HTML file for CELEX 52021PC0731
# Processing HTML file for CELEX 52021PC0721
# Processing HTML file for CELEX 52021PC0753
# Processing HTML file for CELEX 52021PC0706
# Processing HTML file for CELEX 52021PC0709
# Processing HTML file for CELEX 52021PC0664
# Processing HTML file for CELEX 52021PC0656
# Processing HTML file for CELEX 52021PC0665
# Processing HTML file for CELEX 52021PC0663
# Processing HTML file for CELEX 52021PC0627
# Processing HTML file for CELEX 52021PC0634
# Processing HTML file for CELEX 52021PC0582
# Processing HTML file for CELEX 52021PC0547
# Processing HTML file for CELEX 52021PC0581
# Processing HTML file for CELEX 52021PC0579
# Processing HTML file for CELEX 52021PC0574
# WARNING:root:Failed to process CELEX 52021PC0571(01) due to No valid format found
# Processing HTML file for CELEX 52021PC0483
# Processing HTML file for CELEX 52021PC0477
# Processing HTML file for CELEX 52021PC0434
# Processing HTML file for CELEX 52021PC0424
# Processing HTML file for CELEX 52021PC0551
# Processing PDF file for CELEX 52021PC0556
# Processing HTML file for CELEX 52021PC0421
# Processing HTML file for CELEX 52021PC0420
# Processing HTML file for CELEX 52021PC0423
# Processing HTML file for CELEX 52021PC0422
# Processing HTML file for CELEX 52021PC0429
# Processing HTML file for CELEX 52021PC0564
# Processing HTML file for CELEX 52021PC0552
# Processing HTML file for CELEX 52021PC0567
# Processing HTML file for CELEX 52021PC0568
# Processing HTML file for CELEX 52021PC0562
# Processing HTML file for CELEX 52021PC0571
# Processing HTML file for CELEX 52021PC0558
# Processing HTML file for CELEX 52021PC0397
# Processing HTML file for CELEX 52021PC0559
# Processing HTML file for CELEX 52021PC0557
# Processing HTML file for CELEX 52021PC0399
# Processing HTML file for CELEX 52021PC0561
# Processing HTML file for CELEX 52021PC0555
# Processing HTML file for CELEX 52021PC0554
# Processing HTML file for CELEX 52021PC0402
# Processing HTML file for CELEX 52021PC0391
# Processing HTML file for CELEX 52021PC0356
# Processing HTML file for CELEX 52021PC0346
# Processing HTML file for CELEX 52021PC0347
# Processing HTML file for CELEX 52021PC0313
# Processing HTML file for CELEX 52021PC0281
# Processing HTML file for CELEX 52021PC0254
# Processing HTML file for CELEX 52021PC0231
# Processing HTML file for CELEX 52021PC0223
# Processing HTML file for CELEX 52021PC0198
# Processing HTML file for CELEX 52021PC0189
# Processing HTML file for CELEX 52021PC0206
# Processing HTML file for CELEX 52021PC0202
# Processing HTML file for CELEX 52021PC0130
# Processing HTML file for CELEX 52021PC0140
# Processing HTML file for CELEX 52021PC0115
# Processing HTML file for CELEX 52021PC0113
# Processing HTML file for CELEX 52021PC0108
# Processing HTML file for CELEX 52021PC0093
# Processing HTML file for CELEX 52021PC0096
# Processing HTML file for CELEX 52021PC0085
# Processing HTML file for CELEX 52021PC0089
# Processing HTML file for CELEX 52021PC0071
# Processing HTML file for CELEX 52021PC0054
# Processing HTML file for CELEX 52021PC0036
# Processing HTML file for CELEX 52021PC0037
# Processing HTML file for CELEX 52021PC0034
# Processing HTML file for CELEX 52021PC0021
# Processing HTML file for CELEX 52021PC0020
# Processing HTML file for CELEX 52021PC0025
# Processing HTML file for CELEX 52020PC0854
# Processing HTML file for CELEX 52020PC0852
# Processing HTML file for CELEX 52020PC0853
# Processing HTML file for CELEX 52020PC0842
# Processing HTML file for CELEX 52020PC0825
# Processing HTML file for CELEX 52020PC0829
# Processing HTML file for CELEX 52020PC0823
# Processing HTML file for CELEX 52020PC0818
# Processing HTML file for CELEX 52020PC0824
# Processing HTML file for CELEX 52020PC0798
# Processing HTML file for CELEX 52020PC0828
# Processing HTML file for CELEX 52020PC0796
# Processing HTML file for CELEX 52020PC0826
# Processing HTML file for CELEX 52020PC0827
# Processing HTML file for CELEX 52020PC0830
# Processing HTML file for CELEX 52020PC0791
# Processing HTML file for CELEX 52020PC0712
# Processing HTML file for CELEX 52020PC0782
# Processing HTML file for CELEX 52020PC0767
# Processing HTML file for CELEX 52020PC0774
# Processing HTML file for CELEX 52020PC0739
# Processing HTML file for CELEX 52020PC0726
# Processing HTML file for CELEX 52020PC0725
# Processing HTML file for CELEX 52020PC0727
# Processing HTML file for CELEX 52020PC0692
# Processing HTML file for CELEX 52020PC0682
# Processing HTML file for CELEX 52020PC0673
# Processing HTML file for CELEX 52020PC0670
# Processing HTML file for CELEX 52020PC0652
# Processing HTML file for CELEX 52020PC0642
# Processing HTML file for CELEX 52020PC0612
# Processing HTML file for CELEX 52020PC0613
# Processing HTML file for CELEX 52020PC0610
# Processing HTML file for CELEX 52020PC0593
# Processing HTML file for CELEX 52020PC0596
# Processing HTML file for CELEX 52020PC0595
# Processing HTML file for CELEX 52020PC0594
# Processing HTML file for CELEX 52020PC0571
# Processing HTML file for CELEX 52020PC0577
# Processing HTML file for CELEX 52020PC0568
# Processing HTML file for CELEX 52020PC0496
# Processing HTML file for CELEX 52020PC0491
# Processing HTML file for CELEX 52020PC0483
# Processing HTML file for CELEX 52020PC0384
# Processing HTML file for CELEX 52020PC0375
# Processing HTML file for CELEX 52020PC0295
# Processing HTML file for CELEX 52020PC0337
# Processing HTML file for CELEX 52020PC0281
# Processing HTML file for CELEX 52020PC0282
# Processing HTML file for CELEX 52020PC0283
# Processing HTML file for CELEX 52020PC0280
# Processing HTML file for CELEX 52020PC0622
# Processing HTML file for CELEX 52020PC0623
# Processing HTML file for CELEX 52020PC0323
# Processing HTML file for CELEX 52020PC0308
# Processing HTML file for CELEX 52020PC0309
# Processing HTML file for CELEX 52020PC0260
# Processing HTML file for CELEX 52020PC0261
# Processing HTML file for CELEX 52020PC0220
# Processing HTML file for CELEX 52020PC0233
# Processing HTML file for CELEX 52020PC0403
# Processing HTML file for CELEX 52020PC0404
# Processing HTML file for CELEX 52020PC0215
# Processing HTML file for CELEX 52020PC0461
# Processing HTML file for CELEX 52020PC0408
# Processing HTML file for CELEX 52020PC0451
# Processing HTML file for CELEX 52020PC0223
# Processing HTML file for CELEX 52020PC0409
# Processing HTML file for CELEX 52020PC0405
# Processing HTML file for CELEX 52020PC0453
# Processing HTML file for CELEX 52020PC0407
# Processing HTML file for CELEX 52020PC0206
# Processing HTML file for CELEX 52020PC0221
# Processing HTML file for CELEX 52020PC0186
# Processing HTML file for CELEX 52020PC0179
# Processing HTML file for CELEX 52020PC0176
# Processing HTML file for CELEX 52020PC0177
# Processing HTML file for CELEX 52020PC0310
# Processing HTML file for CELEX 52020PC0163
# Processing HTML file for CELEX 52020PC0137
# Processing HTML file for CELEX 52020PC0144
# Processing HTML file for CELEX 52020PC0135
# Processing HTML file for CELEX 52020PC0141
# Processing HTML file for CELEX 52020PC0138
# Processing HTML file for CELEX 52020PC0142
# Processing HTML file for CELEX 52020PC0111
# Processing HTML file for CELEX 52020PC0114
# Processing HTML file for CELEX 52020PC0113
# Processing HTML file for CELEX 52020PC0080
# Processing HTML file for CELEX 52020PC0078
# Processing HTML file for CELEX 52020PC0048
# Processing HTML file for CELEX 52020PC0022
# Processing HTML file for CELEX 52019PC0623
# Processing HTML file for CELEX 52019PC0619
# Processing HTML file for CELEX 52019PC0581
# Processing HTML file for CELEX 52019PC0580
# Processing HTML file for CELEX 52019PC0564
# Processing HTML file for CELEX 52019PC0447
# Processing HTML file for CELEX 52019PC0620
# Processing HTML file for CELEX 52019PC0411
# Processing HTML file for CELEX 52019PC0399
# Processing HTML file for CELEX 52019PC0397
# Processing HTML file for CELEX 52019PC0396
# Processing HTML file for CELEX 52019PC0398
# Processing HTML file for CELEX 52019PC0331
# Processing HTML file for CELEX 52019PC0354
# Processing HTML file for CELEX 52019PC0330
# Processing HTML file for CELEX 52019PC0208
# Processing HTML file for CELEX 52019PC0223
# Processing HTML file for CELEX 52019PC0221
# Processing HTML file for CELEX 52019PC0125
# Processing HTML file for CELEX 52019PC0088
# Processing HTML file for CELEX 52019PC0038
# Processing HTML file for CELEX 52019PC0055
# Processing HTML file for CELEX 52019PC0065
# Processing HTML file for CELEX 52019PC0053
# Processing HTML file for CELEX 52019PC0049
# Processing HTML file for CELEX 52019PC0048
# Processing HTML file for CELEX 52019PC0003
# Processing HTML file for CELEX 52019PC0004
# Processing HTML file for CELEX 52018PC0892
# Processing HTML file for CELEX 52018PC0893
# Processing HTML file for CELEX 52018PC0895
# Processing HTML file for CELEX 52018PC0894
# Processing HTML file for CELEX 52018PC0891
# Processing HTML file for CELEX 52018PC0817
# Processing HTML file for CELEX 52018PC0745
# Processing HTML file for CELEX 52018PC0744
# Processing HTML file for CELEX 52018PC0719
# Processing HTML file for CELEX 52018PC0630
# Processing HTML file for CELEX 52018PC0634
# Processing HTML file for CELEX 52018PC0636
# Processing HTML file for CELEX 52018PC0631
# Processing HTML file for CELEX 52018PC0640
# Processing HTML file for CELEX 52018PC0639
# Processing HTML file for CELEX 52018PC0614
# Processing HTML file for CELEX 52018PC0577
# Processing HTML file for CELEX 52018PC0568
# Processing HTML file for CELEX 52018PC0567
# Processing HTML file for CELEX 52018PC0365
# Processing HTML file for CELEX 52018PC0499
# Processing HTML file for CELEX 52018PC0498
# Processing HTML file for CELEX 52018PC0465
# Processing HTML file for CELEX 52018PC0460
# Processing HTML file for CELEX 52018PC0473
# Processing HTML file for CELEX 52018PC0476
# Processing HTML file for CELEX 52018PC0472
# Processing HTML file for CELEX 52018PC0471
# Processing HTML file for CELEX 52018PC0474
# Processing HTML file for CELEX 52018PC0390
# Processing HTML file for CELEX 52018PC0440
# Processing HTML file for CELEX 52018PC0443
# Processing HTML file for CELEX 52018PC0442
# Processing HTML file for CELEX 52018PC0447
# Processing HTML file for CELEX 52018PC0439
# Processing HTML file for CELEX 52018PC0434
# Processing HTML file for CELEX 52018PC0436
# Processing HTML file for CELEX 52018PC0441
# Processing HTML file for CELEX 52018PC0438
# Processing HTML file for CELEX 52018PC0435
# Processing HTML file for CELEX 52018PC0397
# Processing HTML file for CELEX 52018PC0392
# Processing HTML file for CELEX 52018PC0385
# Processing HTML file for CELEX 52018PC0393
# Processing HTML file for CELEX 52018PC0394
# Processing HTML file for CELEX 52018PC0378
# Processing HTML file for CELEX 52018PC0391
# Processing HTML file for CELEX 52018PC0381
# Processing HTML file for CELEX 52018PC0379
# Processing HTML file for CELEX 52018PC0369
# Processing HTML file for CELEX 52018PC0387
# Processing HTML file for CELEX 52018PC0367
# Processing HTML file for CELEX 52018PC0380
# Processing HTML file for CELEX 52018PC0384
# Processing HTML file for CELEX 52018PC0383
# Processing HTML file for CELEX 52018PC0366
# Processing HTML file for CELEX 52018PC0368
# Processing HTML file for CELEX 52018PC0382
# Processing HTML file for CELEX 52018PC0386
# Processing HTML file for CELEX 52018PC0375
# Processing HTML file for CELEX 52018PC0372
# Processing HTML file for CELEX 52018PC0374
# Processing HTML file for CELEX 52018PC0373
# Processing HTML file for CELEX 52018PC0340
# Processing HTML file for CELEX 52018PC0317
# Processing HTML file for CELEX 52018PC0337
# Processing HTML file for CELEX 52018PC0341
# Processing HTML file for CELEX 52018PC0316
# Processing HTML file for CELEX 52018PC0338
# Processing HTML file for CELEX 52018PC0354
# Processing HTML file for CELEX 52018PC0331
# Processing HTML file for CELEX 52018PC0355
# Processing HTML file for CELEX 52018PC0336
# Processing HTML file for CELEX 52018PC0315
# Processing HTML file for CELEX 52018PC0353
# Processing HTML file for CELEX 52018PC0339
# Processing HTML file for CELEX 52018PC0312
# Processing HTML file for CELEX 52018PC0302
# Processing HTML file for CELEX 52018PC0279
# Processing HTML file for CELEX 52018PC0296
# Processing HTML file for CELEX 52018PC0277
# Processing HTML file for CELEX 52018PC0303
# Processing HTML file for CELEX 52018PC0275
# Processing HTML file for CELEX 52018PC0274
# Processing HTML file for CELEX 52018PC0284
# Processing HTML file for CELEX 52018PC0286
# Processing HTML file for CELEX 52018PC0278
# Processing HTML file for CELEX 52018PC0307
# Processing HTML file for CELEX 52018PC0289
# Processing HTML file for CELEX 52018PC0259
# Processing HTML file for CELEX 52018PC0324
# Processing HTML file for CELEX 52018PC0231
# Processing HTML file for CELEX 52018PC0238
# Processing HTML file for CELEX 52018PC0239
# Processing HTML file for CELEX 52018PC0234
# Processing HTML file for CELEX 52018PC0241
# Processing HTML file for CELEX 52018PC0229
# Processing HTML file for CELEX 52018PC0218
# Processing HTML file for CELEX 52018PC0212
# Processing HTML file for CELEX 52018PC0199
# Processing HTML file for CELEX 52018PC0225
# Processing HTML file for CELEX 52018PC0226
# Processing HTML file for CELEX 52018PC0206
# Processing HTML file for CELEX 52018PC0209
# Processing HTML file for CELEX 52018PC0213
# Processing HTML file for CELEX 52018PC0179
# Processing HTML file for CELEX 52018PC0173
# Processing HTML file for CELEX 52018PC0185
# Processing HTML file for CELEX 52018PC0184
# Processing HTML file for CELEX 52018PC0171
# Processing HTML file for CELEX 52018PC0163
# Processing HTML file for CELEX 52018PC0149
# Processing HTML file for CELEX 52018PC0144
# Processing HTML file for CELEX 52018PC0143
# Processing HTML file for CELEX 52018PC0137
# Processing HTML file for CELEX 52018PC0252
# Processing HTML file for CELEX 52018PC0139
# Processing HTML file for CELEX 52018PC0131
# Processing HTML file for CELEX 52018PC0135
# Processing HTML file for CELEX 52018PC0134
# Processing HTML file for CELEX 52018PC0094
# Processing HTML file for CELEX 52018PC0093
# Processing HTML file for CELEX 52018PC0110
# Processing HTML file for CELEX 52018PC0092
# Processing HTML file for CELEX 52018PC0096
# Processing HTML file for CELEX 52018PC0127
# Processing HTML file for CELEX 52018PC0115
# Processing HTML file for CELEX 52018PC0113
# Processing HTML file for CELEX 52018PC0099
# Processing HTML file for CELEX 52018PC0085
# Processing HTML file for CELEX 52017PC0753
# Processing HTML file for CELEX 52018PC0051
# Processing HTML file for CELEX 52018PC0033
# Processing HTML file for CELEX 52017PC0790
# Processing HTML file for CELEX 52017PC0792
# Processing HTML file for CELEX 52017PC0797
# Processing HTML file for CELEX 52017PC0791
# Processing HTML file for CELEX 52017PC0795
# Processing HTML file for CELEX 52017PC0796
# Processing HTML file for CELEX 52017PC0769
# Processing HTML file for CELEX 52017PC0774
# Processing HTML file for CELEX 52017PC0793
# Processing HTML file for CELEX 52017PC0794
# Processing HTML file for CELEX 52017PC0826
# Processing HTML file for CELEX 52017PC0825
# Processing HTML file for CELEX 52017PC0742
# Processing HTML file for CELEX 52017PC0734
# Processing HTML file for CELEX 52017PC0735
# Processing HTML file for CELEX 52017PC0772
# Processing HTML file for CELEX 52017PC0643
# Processing HTML file for CELEX 52017PC0648
# Processing HTML file for CELEX 52017PC0676
# Processing HTML file for CELEX 52017PC0660
# Processing HTML file for CELEX 52017PC0653
# Processing HTML file for CELEX 52017PC0647
# Processing HTML file for CELEX 52017PC0565
# Processing HTML file for CELEX 52017PC0559
# Processing HTML file for CELEX 52017PC0571
# Processing HTML file for CELEX 52017PC0548
# Processing PDF file for CELEX 52017PC0545
# Processing HTML file for CELEX 52017PC0538
# Processing HTML file for CELEX 52017PC0536
# Processing HTML file for CELEX 52017PC0537
# Processing HTML file for CELEX 52017PC0482
# Processing HTML file for CELEX 52017PC0477
# Processing HTML file for CELEX 52017PC0495
# Processing HTML file for CELEX 52017PC0481
# Processing HTML file for CELEX 52017PC0487
# Processing HTML file for CELEX 52017PC0489
# Processing HTML file for CELEX 52017PC0424
# Processing HTML file for CELEX 52017PC0422
# Processing HTML file for CELEX 52017PC0385
# Processing HTML file for CELEX 52017PC0375
# Processing HTML file for CELEX 52017PC0353
# Processing HTML file for CELEX 52017PC0344
# Processing HTML file for CELEX 52017PC0352
# Processing HTML file for CELEX 52017PC0343
# Processing HTML file for CELEX 52017PC0329
# Processing HTML file for CELEX 52017PC0331
# Processing HTML file for CELEX 52017PC0289
# Processing HTML file for CELEX 52017PC0294
# Processing HTML file for CELEX 52017PC0262
# Processing HTML file for CELEX 52017PC0282
# Processing HTML file for CELEX 52017PC0281
# Processing HTML file for CELEX 52017PC0279
# Processing HTML file for CELEX 52017PC0277
# Processing HTML file for CELEX 52017PC0278
# Processing HTML file for CELEX 52017PC0275
# Processing HTML file for CELEX 52017PC0208
# Processing HTML file for CELEX 52017PC0257
# Processing HTML file for CELEX 52017PC0256
# Processing HTML file for CELEX 52017PC0253
# Processing HTML file for CELEX 52017PC0150
# Processing HTML file for CELEX 52017PC0128
# Processing HTML file for CELEX 52017PC0142
# Processing HTML file for CELEX 52017PC0136
# Processing HTML file for CELEX 52017PC0114
# Processing HTML file for CELEX 52017PC0097
# Processing HTML file for CELEX 52017PC0085
# Processing HTML file for CELEX 52016PC0851
# Processing HTML file for CELEX 52017PC0054
# Processing HTML file for CELEX 52017PC0047
# Processing HTML file for CELEX 52017PC0038
# Processing HTML file for CELEX 52017PC0014
# Processing HTML file for CELEX 52017PC0010
# Processing HTML file for CELEX 52016PC0821
# Processing HTML file for CELEX 52017PC0011
# Processing HTML file for CELEX 52017PC0008
# Processing HTML file for CELEX 52016PC0824
# Processing HTML file for CELEX 52016PC0822
# Processing HTML file for CELEX 52016PC0823
# Processing HTML file for CELEX 52016PC0854
# Processing HTML file for CELEX 52016PC0853
# Processing HTML file for CELEX 52016PC0850
# Processing HTML file for CELEX 52016PC0852
# Processing HTML file for CELEX 52016PC0825
# Processing HTML file for CELEX 52016PC0819
# Processing HTML file for CELEX 52016PC0881
# Processing HTML file for CELEX 52016PC0818
# Processing HTML file for CELEX 52016PC0826
# Processing HTML file for CELEX 52016PC0882
# Processing HTML file for CELEX 52016PC0883
# Processing HTML file for CELEX 52016PC0789
# Processing HTML file for CELEX 52016PC0799
# Processing HTML file for CELEX 52016PC0798
# Processing HTML file for CELEX 52016PC0815
# Processing HTML file for CELEX 52016PC0788
# Processing HTML file for CELEX 52016PC0786
# Processing HTML file for CELEX 52016PC0745
# Processing HTML file for CELEX 52016PC0767
# Processing HTML file for CELEX 52016PC0862
# Processing HTML file for CELEX 52016PC0863
# Processing HTML file for CELEX 52016PC0765
# Processing HTML file for CELEX 52016PC0864
# Processing HTML file for CELEX 52016PC0861
# Processing HTML file for CELEX 52016PC0750
# Processing HTML file for CELEX 52016PC0761
# Processing HTML file for CELEX 52016PC0759
# Processing HTML file for CELEX 52016PC0778
# Processing HTML file for CELEX 52016PC0856
# Processing HTML file for CELEX 52016PC0723
# Processing HTML file for CELEX 52016PC0731
# Processing HTML file for CELEX 52016PC0709
# Processing HTML file for CELEX 52016PC0721
# Processing HTML file for CELEX 52016PC0702
# Processing HTML file for CELEX 52016PC0662
# Processing HTML file for CELEX 52016PC0625
# Processing HTML file for CELEX 52016PC0616
# Processing HTML file for CELEX 52016PC0631
# Processing HTML file for CELEX 52016PC0593
# Processing HTML file for CELEX 52016PC0595
# Processing HTML file for CELEX 52016PC0605
# Processing HTML file for CELEX 52016PC0597
# Processing HTML file for CELEX 52016PC0591
# Processing HTML file for CELEX 52016PC0583
# Processing HTML file for CELEX 52016PC0596
# Processing HTML file for CELEX 52016PC0590
# Processing HTML file for CELEX 52016PC0594
# Processing HTML file for CELEX 52016PC0582
# Processing HTML file for CELEX 52016PC0589
# Processing HTML file for CELEX 52016PC0586
# Processing HTML file for CELEX 52016PC0557
# Processing HTML file for CELEX 52016PC0491
# Processing HTML file for CELEX 52016PC0543
# Processing HTML file for CELEX 52016PC0547
# Processing HTML file for CELEX 52016PC0551
# Processing HTML file for CELEX 52016PC0532
# Processing HTML file for CELEX 52016PC0528
# Processing HTML file for CELEX 52016PC0531
# Processing HTML file for CELEX 52016PC0493
# Processing HTML file for CELEX 52016PC0482
# Processing HTML file for CELEX 52016PC0479
# Processing HTML file for CELEX 52016PC0477
# Processing HTML file for CELEX 52016PC0460
# Processing HTML file for CELEX 52016PC0467
# Processing HTML file for CELEX 52016PC0465
# Processing HTML file for CELEX 52016PC0466
# Processing HTML file for CELEX 52016PC0468
# Processing HTML file for CELEX 52016PC0461
# Processing HTML file for CELEX 52016PC0450
# Processing HTML file for CELEX 52016PC0447
# Processing HTML file for CELEX 52016PC0434
# Processing HTML file for CELEX 52016PC0314
# Processing HTML file for CELEX 52016PC0431
# Processing HTML file for CELEX 52016PC0418
# Processing HTML file for CELEX 52016PC0400
# Processing HTML file for CELEX 52016PC0401
# Processing HTML file for CELEX 52016PC0399
# Processing HTML file for CELEX 52016PC0388
# Processing HTML file for CELEX 52016PC0378
# Processing HTML file for CELEX 52016PC0371
# Processing HTML file for CELEX 52016PC0369
# Processing HTML file for CELEX 52016PC0370
# Processing HTML file for CELEX 52016PC0315
# Processing HTML file for CELEX 52016PC0317
# Processing HTML file for CELEX 52016PC0289
# Processing HTML file for CELEX 52016PC0287
# Processing HTML file for CELEX 52016PC0283
# Processing HTML file for CELEX 52016PC0285
# Processing HTML file for CELEX 52016PC0273
# Processing HTML file for CELEX 52016PC0248
# Processing HTML file for CELEX 52016PC0272
# Processing HTML file for CELEX 52016PC0277
# Processing HTML file for CELEX 52016PC0270
# Processing HTML file for CELEX 52016PC0271
# Processing HTML file for CELEX 52016PC0290
# Processing HTML file for CELEX 52016PC0279
# Processing HTML file for CELEX 52016PC0236
# Processing HTML file for CELEX 52016PC0202
# Processing HTML file for CELEX 52016PC0198
# Processing HTML file for CELEX 52016PC0194
# Processing HTML file for CELEX 52016PC0196
# Processing HTML file for CELEX 52016PC0159
# Processing HTML file for CELEX 52016PC0157
# Processing HTML file for CELEX 52016PC0134
# Processing HTML file for CELEX 52016PC0142
# Processing HTML file for CELEX 52016PC0128
# Processing HTML file for CELEX 52016PC0082
# Processing HTML file for CELEX 52016PC0113
# Processing HTML file for CELEX 52015PC0701
# Processing HTML file for CELEX 52016PC0053
# Processing HTML file for CELEX 52016PC0052
# Processing HTML file for CELEX 52016PC0067
# Processing HTML file for CELEX 52016PC0056
# Processing HTML file for CELEX 52016PC0057
# Processing HTML file for CELEX 52016PC0044
# Processing HTML file for CELEX 52016PC0043
# Processing HTML file for CELEX 52016PC0039
# Processing HTML file for CELEX 52016PC0031
# Processing HTML file for CELEX 52016PC0007
# Processing HTML file for CELEX 52015PC0750
# Processing HTML file for CELEX 52015PC0670
# Processing HTML file for CELEX 52015PC0668
# Processing HTML file for CELEX 52015PC0671
# Processing HTML file for CELEX 52015PC0669
# Processing HTML file for CELEX 52015PC0648
# Processing HTML file for CELEX 52015PC0667
# Processing HTML file for CELEX 52015PC0586
# Processing HTML file for CELEX 52015PC0636
# Processing HTML file for CELEX 52015PC0627
# Processing HTML file for CELEX 52015PC0634
# Processing HTML file for CELEX 52015PC0635
# Processing HTML file for CELEX 52015PC0613
# Processing HTML file for CELEX 52015PC0615
# Processing HTML file for CELEX 52015PC0593
# Processing HTML file for CELEX 52015PC0625
# Processing HTML file for CELEX 52015PC0596
# Processing HTML file for CELEX 52015PC0595
# Processing HTML file for CELEX 52015PC0616
# Processing HTML file for CELEX 52015PC0594
# Processing HTML file for CELEX 52015PC0583
# Processing HTML file for CELEX 52015PC0496
# Processing HTML file for CELEX 52015PC0472
# Processing HTML file for CELEX 52015PC0473
# Processing HTML file for CELEX 52015PC0460
# Processing HTML file for CELEX 52015PC0450
# Processing HTML file for CELEX 52015PC0452
# Processing HTML file for CELEX 52015PC0365
# Processing HTML file for CELEX 52015PC0337
# Processing HTML file for CELEX 52015PC0341
# Processing HTML file for CELEX 52015PC0303
# Processing HTML file for CELEX 52015PC0294
# Processing HTML file for CELEX 52015PC0282
# Processing PDF file for CELEX 52015PC0220
# Processing PDF file for CELEX 52015PC0180
# Processing HTML file for CELEX 52015PC0177
# Processing PDF file for CELEX 52015PC0174
# Processing HTML file for CELEX 52015PC0157
# Processing HTML file for CELEX 52015PC0155
# Processing HTML file for CELEX 52015PC0154
# Processing HTML file for CELEX 52015PC0141
# Processing HTML file for CELEX 52015PC0121
# Processing HTML file for CELEX 52015PC0045
# Processing HTML file for CELEX 52015PC0048
# Processing HTML file for CELEX 52015PC0046
# Processing PDF file for CELEX 52006PC0543
# Processing PDF file for CELEX 52006PC0286
# Processing HTML file for CELEX 52015PC0008
# Processing HTML file for CELEX 52015PC0010
# Processing HTML file for CELEX 52015PC0005
# Processing HTML file for CELEX 52014PC0724
# Processing HTML file for CELEX 52014PC0713
# Processing HTML file for CELEX 52014PC0715
# Processing HTML file for CELEX 52014PC0714
# Processing HTML file for CELEX 52014PC0707
# Processing HTML file for CELEX 52014PC0667
# Processing HTML file for CELEX 52014PC0660
# Processing HTML file for CELEX 52014PC0622
# Processing HTML file for CELEX 52014PC0614
# Processing HTML file for CELEX 52014PC0585
# Processing HTML file for CELEX 52014PC0605
# Processing HTML file for CELEX 52014PC0593
# Processing HTML file for CELEX 52014PC0594
# Processing HTML file for CELEX 52014PC0581
# Processing HTML file for CELEX 52014PC0586
# Processing HTML file for CELEX 52014PC0597
# Processing HTML file for CELEX 52014PC0556
# Processing HTML file for CELEX 52014PC0558
# Processing HTML file for CELEX 52014PC0557
# Processing HTML file for CELEX 52014PC0542
# Processing HTML file for CELEX 52014PC0476
# Processing HTML file for CELEX 52014PC0465
# Processing HTML file for CELEX 52014PC0466
# Processing HTML file for CELEX 52014PC0457
# Processing HTML file for CELEX 52014PC0397
# Processing HTML file for CELEX 52014PC0443
# Processing HTML file for CELEX 52014PC0394
# Processing HTML file for CELEX 52014PC0382
# Processing HTML file for CELEX 52014PC0379
# Processing HTML file for CELEX 52014PC0367
# Processing HTML file for CELEX 52014PC0386
# Processing HTML file for CELEX 52014PC0375
# Processing HTML file for CELEX 52014PC0374
# Processing HTML file for CELEX 52014PC0358
# Processing HTML file for CELEX 52014PC0344
# Processing HTML file for CELEX 52014PC0340
# Processing HTML file for CELEX 52014PC0343
# Processing HTML file for CELEX 52014PC0345
# Processing HTML file for CELEX 52014PC0341
# Processing HTML file for CELEX 52014PC0317
# Processing HTML file for CELEX 52014PC0319
# Processing HTML file for CELEX 52014PC0323
# Processing HTML file for CELEX 52014PC0318
# Processing HTML file for CELEX 52014PC0322
# Processing HTML file for CELEX 52014PC0321
# Processing HTML file for CELEX 52014PC0308
# Processing HTML file for CELEX 52014PC0304
# Processing HTML file for CELEX 52014PC0305
# Processing HTML file for CELEX 52013PC0678
# Processing HTML file for CELEX 52014PC0265
# Processing HTML file for CELEX 52014PC0258
# Processing HTML file for CELEX 52014PC0246
# Processing HTML file for CELEX 52014PC0212
# Processing HTML file for CELEX 52014PC0221
# Processing HTML file for CELEX 52014PC0213
# Processing HTML file for CELEX 52014PC0163
# Processing HTML file for CELEX 52014PC0164
# Processing HTML file for CELEX 52014PC0167
# Processing HTML file for CELEX 52014PC0186
# Processing HTML file for CELEX 52014PC0187
# Processing HTML file for CELEX 52014PC0180
# Processing HTML file for CELEX 52014PC0175
# Processing HTML file for CELEX 52004PC0486
# Processing HTML file for CELEX 52014PC0174
# Processing HTML file for CELEX 52014PC0166
# Processing HTML file for CELEX 52014PC0111
# Processing HTML file for CELEX 52012PC0280
# Processing HTML file for CELEX 52012PC0360
# Processing HTML file for CELEX 52014PC0004
# Processing HTML file for CELEX 52014PC0005
# Processing HTML file for CELEX 52014PC0066
# Processing HTML file for CELEX 52014PC0040
# Processing HTML file for CELEX 52014PC0043
# Processing HTML file for CELEX 52014PC0032
# Processing HTML file for CELEX 52014PC0028
# Processing HTML file for CELEX 52014PC0020
# Processing HTML file for CELEX 52014PC0006
# Processing HTML file for CELEX 52013PC0937
# Processing HTML file for CELEX 52014PC0001
# Processing HTML file for CELEX 52013PC0821
# Processing HTML file for CELEX 52013PC0822
# Processing HTML file for CELEX 52013PC0824
# Processing HTML file for CELEX 52013PC0853
# Processing HTML file for CELEX 52013PC0920
# Processing HTML file for CELEX 52013PC0919
# Processing HTML file for CELEX 52013PC0894
# Processing HTML file for CELEX 52013PC0892
# Processing HTML file for CELEX 52013PC0889
# Processing HTML file for CELEX 52013PC0884
# Processing HTML file for CELEX 52013PC0896
# Processing HTML file for CELEX 52013PC0895
# Processing HTML file for CELEX 52013PC0860
# Processing HTML file for CELEX 52013PC0813
# Processing HTML file for CELEX 52013PC0796
# Processing HTML file for CELEX 52013PC0812
# Processing HTML file for CELEX 52013PC0794
# Processing HTML file for CELEX 52013PC0798
# Processing HTML file for CELEX 52013PC0769
# Processing HTML file for CELEX 52013PC0761
# Processing HTML file for CELEX 52013PC0757
# Processing HTML file for CELEX 52013PC0751
# Processing HTML file for CELEX 52013PC0722
# Processing HTML file for CELEX 52013PC0680
# Processing HTML file for CELEX 52013PC0639
# Processing HTML file for CELEX 52013PC0641
# Processing HTML file for CELEX 52013PC0619
# Processing HTML file for CELEX 52013PC0618
# Processing HTML file for CELEX 52013PC0627
# Processing HTML file for CELEX 52013PC0622
# Processing HTML file for CELEX 52013PC0621
# Processing HTML file for CELEX 52013PC0620
# Processing HTML file for CELEX 52013PC0615
# Processing HTML file for CELEX 52013PC0611
# Processing HTML file for CELEX 52013PC0015
# Processing HTML file for CELEX 52013PC0471
# Processing HTML file for CELEX 52013PC0484
# Processing HTML file for CELEX 52013PC0480
# Processing HTML file for CELEX 52013PC0578
# Processing HTML file for CELEX 52013PC0579
# Processing HTML file for CELEX 52013PC0451
# Processing HTML file for CELEX 52013PC0554
# Processing HTML file for CELEX 52013PC0522
# Processing HTML file for CELEX 52013PC0560
# Processing HTML file for CELEX 52013PC0547
# Processing HTML file for CELEX 52013PC0550
# Processing HTML file for CELEX 52013PC0535
# Processing HTML file for CELEX 52013PC0525
# Processing HTML file for CELEX 52013PC0520
# Processing HTML file for CELEX 52013PC0521
# Processing HTML file for CELEX 52013PC0498
# Processing HTML file for CELEX 52013PC0497
# Processing HTML file for CELEX 52013PC0500
# Processing HTML file for CELEX 52013PC0493
# Processing HTML file for CELEX 52013PC0512
# Processing HTML file for CELEX 52013PC0516
# Processing HTML file for CELEX 52013PC0509
# Processing HTML file for CELEX 52013PC0462
# Processing HTML file for CELEX 52013PC0449
# Processing HTML file for CELEX 52013PC0452
# Processing HTML file for CELEX 52013PC0472
# Processing HTML file for CELEX 52013PC0441
# Processing HTML file for CELEX 52013PC0427
# Processing HTML file for CELEX 52013PC0428
# Processing HTML file for CELEX 52013PC0430
# Processing HTML file for CELEX 52013PC0418
# Processing HTML file for CELEX 52013PC0417
# Processing HTML file for CELEX 52013PC0404
# Processing HTML file for CELEX 52013PC0315
# Processing HTML file for CELEX 52013PC0316
# Processing HTML file for CELEX 52013PC0409
# Processing HTML file for CELEX 52013PC0410
# Processing HTML file for CELEX 52013PC0327
# Processing HTML file for CELEX 52013PC0342
# Processing HTML file for CELEX 52013PC0311
# Processing HTML file for CELEX 52013PC0312
# Processing HTML file for CELEX 52013PC0293
# Processing HTML file for CELEX 52013PC0296
# Processing HTML file for CELEX 52013PC0301
# Processing HTML file for CELEX 52013PC0288
# Processing HTML file for CELEX 52013PC0266
# Processing HTML file for CELEX 52013PC0260
# Processing HTML file for CELEX 52013PC0267
# Processing PDF file for CELEX 52013PC0265
# Processing HTML file for CELEX 52013PC0247
# Processing HTML file for CELEX 52013PC0262
# Processing HTML file for CELEX 52013PC0250
# Processing HTML file for CELEX 52013PC0242
# Processing HTML file for CELEX 52013PC0236
# Processing HTML file for CELEX 52013PC0228
# Processing HTML file for CELEX 52013PC0207
# Processing HTML file for CELEX 52013PC0195
# Processing HTML file for CELEX 52013PC0226
# Processing HTML file for CELEX 52013PC0197
# Processing HTML file for CELEX 52013PC0192
# Processing HTML file for CELEX 52013PC0193
# Processing HTML file for CELEX 52013PC0187
# Processing HTML file for CELEX 52013PC0185
# Processing HTML file for CELEX 52013PC0174
# Processing HTML file for CELEX 52013PC0161
# Processing HTML file for CELEX 52013PC0173
# Processing HTML file for CELEX 52013PC0151
# Processing HTML file for CELEX 52013PC0162
# Processing HTML file for CELEX 52013PC0155
# Processing HTML file for CELEX 52013PC0159
# Processing HTML file for CELEX 52013PC0147
# Processing HTML file for CELEX 52013PC0153
# Processing HTML file for CELEX 52013PC0130
# Processing HTML file for CELEX 52013PC0133
# Processing HTML file for CELEX 52013PC0097
# Processing HTML file for CELEX 52013PC0096
# Processing HTML file for CELEX 52013PC0095
# Processing HTML file for CELEX 52013PC0107
# Processing HTML file for CELEX 52013PC0106
# Processing HTML file for CELEX 52013PC0102
# Processing HTML file for CELEX 52013PC0075
# Processing HTML file for CELEX 52013PC0078
# Processing HTML file for CELEX 52013PC0048
# Processing HTML file for CELEX 52013PC0045
# Processing HTML file for CELEX 52013PC0040
# Processing HTML file for CELEX 52013PC0042
# Processing HTML file for CELEX 52013PC0044
# Processing HTML file for CELEX 52013PC0028
# Processing HTML file for CELEX 52013PC0031
# Processing HTML file for CELEX 52013PC0027
# Processing HTML file for CELEX 52013PC0029
# Processing HTML file for CELEX 52013PC0030
# Processing HTML file for CELEX 52013PC0026
# Processing HTML file for CELEX 52013PC0018
# Processing HTML file for CELEX 52013PC0009
# Processing HTML file for CELEX 52012PC0788
# Processing HTML file for CELEX 52012PC0773
# Processing HTML file for CELEX 52012PC0782
# Processing HTML file for CELEX 52012PC0772
# Processing HTML file for CELEX 52012PC0776
# Processing HTML file for CELEX 52012PC0724
# Processing HTML file for CELEX 52012PC0721
# Processing HTML file for CELEX 52012PC0697
# Processing HTML file for CELEX 52012PC0744
# Processing HTML file for CELEX 52012PC0712
# Processing HTML file for CELEX 52012PC0710
# Processing HTML file for CELEX 52012PC0614
# Processing HTML file for CELEX 52012PC0650
# Processing HTML file for CELEX 52012PC0643
# Processing HTML file for CELEX 52012PC0595
# Processing HTML file for CELEX 52012PC0628
# Processing HTML file for CELEX 52012PC0617
# Processing HTML file for CELEX 52012PC0591
# Processing HTML file for CELEX 52012PC0584
# Processing HTML file for CELEX 52012PC0576
# Processing HTML file for CELEX 52012PC0530
# Processing HTML file for CELEX 52012PC0548
# Processing HTML file for CELEX 52012PC0542
# Processing HTML file for CELEX 52012PC0541
# Processing HTML file for CELEX 52012PC0521
# Processing HTML file for CELEX 52012PC0526
# Processing HTML file for CELEX 52012PC0527
# Processing HTML file for CELEX 52012PC0514
# Processing HTML file for CELEX 52012PC0524
# Processing HTML file for CELEX 52012PC0512
# Processing HTML file for CELEX 52012PC0499
# Processing HTML file for CELEX 52012PC0498
# Processing HTML file for CELEX 52012PC0471
# Processing HTML file for CELEX 52012PC0447
# Processing HTML file for CELEX 52012PC0449
# Processing HTML file for CELEX 52012PC0377
# Processing HTML file for CELEX 52012PC0432
# Processing HTML file for CELEX 52012PC0413
# Processing HTML file for CELEX 52012PC0416
# Processing HTML file for CELEX 52012PC0407
# Processing HTML file for CELEX 52012PC0371
# Processing HTML file for CELEX 52012PC0403
# Processing HTML file for CELEX 52012PC0369
# Processing HTML file for CELEX 52012PC0372
# Processing HTML file for CELEX 52012PC0363
# Processing HTML file for CELEX 52012PC0382
# Processing HTML file for CELEX 52012PC0394
# Processing HTML file for CELEX 52012PC0381
# Processing HTML file for CELEX 52012PC0393
# Processing HTML file for CELEX 52012PC0350
# Processing HTML file for CELEX 52012PC0352
# Processing HTML file for CELEX 52012PC0270
# Processing HTML file for CELEX 52012PC0355
# Processing HTML file for CELEX 52012PC0343
# Processing HTML file for CELEX 52012PC0329
# Processing HTML file for CELEX 52012PC0332
# Processing HTML file for CELEX 52012PC0298
# Processing HTML file for CELEX 52012PC0335
# Processing HTML file for CELEX 52012PC0277
# Processing HTML file for CELEX 52012PC0238
# Processing HTML file for CELEX 52012PC0217
# Processing HTML file for CELEX 52012PC0167
# Processing HTML file for CELEX 52012PC0172
# Processing HTML file for CELEX 52012PC0164
# Processing HTML file for CELEX 52012PC0118
# Processing HTML file for CELEX 52012PC0129
# Processing HTML file for CELEX 52012PC0155
# ...
# Processing HTML file for CELEX 52003PC0777(03)
# Processing HTML file for CELEX 52003PC0777(02)
# Processing HTML file for CELEX 52003PC0797(01)
# Processing HTML file for CELEX 52003PC0797(02)
# Processing HTML file for CELEX 52003PC0808
# Processing HTML file for CELEX 52003PC0740
# Processing HTML file for CELEX 52003PC0796
# Processing HTML file for CELEX 52003PC0739
# Processing HTML file for CELEX 52003PC0767
# Processing HTML file for CELEX 52003PC0741
# Processing HTML file for CELEX 52003PC0758
# Processing HTML file for CELEX 52003PC0763
# Processing HTML file for CELEX 52003PC0621
# Processing HTML file for CELEX 52003PC0628
# Processing HTML file for CELEX 52003PC0732
# Processing HTML file for CELEX 52003PC0723
# Processing HTML file for CELEX 52003PC0703
# Processing HTML file for CELEX 52003PC0700
# Processing HTML file for CELEX 52003PC0689
# Processing HTML file for CELEX 52003PC0644(01)
# Processing HTML file for CELEX 52003PC0671
# Processing HTML file for CELEX 52003PC0644(02)
# Processing HTML file for CELEX 52003PC0667
# Processing HTML file for CELEX 52003PC0659
# Processing HTML file for CELEX 52003PC0639
# Processing HTML file for CELEX 52003PC0624
# Processing HTML file for CELEX 52003PC0622
# Processing HTML file for CELEX 52003PC0627
# Processing HTML file for CELEX 52003PC0605
# Processing HTML file for CELEX 52003PC0586
# Processing HTML file for CELEX 52003PC0158
# Processing HTML file for CELEX 52003PC0566
# Processing HTML file for CELEX 52003PC0559
# Processing HTML file for CELEX 52003PC0550
# Processing HTML file for CELEX 52003PC0537
# Processing HTML file for CELEX 52003PC0522
# Processing HTML file for CELEX 52003PC0529
# Processing HTML file for CELEX 52003PC0524
# Processing HTML file for CELEX 52003PC0523
# Processing HTML file for CELEX 52003PC0509
# Processing HTML file for CELEX 52003PC0510
# Processing HTML file for CELEX 52003PC0507
# Processing HTML file for CELEX 52003PC0492
# Processing HTML file for CELEX 52003PC0441
# Processing HTML file for CELEX 52003PC0440
# Processing HTML file for CELEX 52003PC0478
# Processing HTML file for CELEX 52003PC0453
# Processing HTML file for CELEX 52003PC0468
# Processing HTML file for CELEX 52003PC0465
# Processing HTML file for CELEX 52003PC0467
# Processing HTML file for CELEX 52003PC0403
# Processing HTML file for CELEX 52003PC0448
# Processing HTML file for CELEX 52003PC0446
# Processing HTML file for CELEX 52003PC0452
# Processing HTML file for CELEX 52003PC0427
# Processing HTML file for CELEX 52003PC0443
# Processing HTML file for CELEX 52003PC0431
# Processing HTML file for CELEX 52003PC0424
# Processing HTML file for CELEX 52003PC0423
# Processing HTML file for CELEX 52003PC0418
# Processing HTML file for CELEX 52003PC0413
# Processing HTML file for CELEX 52003PC0278
# Processing HTML file for CELEX 52003PC0402
# Processing HTML file for CELEX 52003PC0406
# Processing HTML file for CELEX 52003PC0379
# Processing HTML file for CELEX 52003PC0378
# Processing HTML file for CELEX 52003PC0361
# Processing HTML file for CELEX 52003PC0356
# Processing HTML file for CELEX 52003PC0362
# Processing HTML file for CELEX 52003PC0364
# Processing HTML file for CELEX 52003PC0275
# Processing HTML file for CELEX 52003PC0333
# Processing HTML file for CELEX 52003PC0350
# Processing HTML file for CELEX 52003PC0355
# Processing HTML file for CELEX 52003PC0272
# Processing HTML file for CELEX 52003PC0279
# Processing HTML file for CELEX 52003PC0273
# Processing HTML file for CELEX 52003PC0319
# Processing HTML file for CELEX 52003PC0138
# Processing HTML file for CELEX 52003PC0229
# Processing HTML file for CELEX 52003PC0185
# Processing HTML file for CELEX 52003PC0132
# Processing HTML file for CELEX 52003PC0219
# Processing HTML file for CELEX 52003PC0241
# Processing HTML file for CELEX 52003PC0252
# Processing HTML file for CELEX 52003PC0243
# Processing HTML file for CELEX 52003PC0203
# Processing HTML file for CELEX 52003PC0242
# Processing HTML file for CELEX 52003PC0218
# Processing HTML file for CELEX 52003PC0220
# Processing HTML file for CELEX 52003PC0207
# Processing HTML file for CELEX 52003PC0180
# Processing HTML file for CELEX 52003PC0187
# Processing HTML file for CELEX 52003PC0188
# Processing HTML file for CELEX 52003PC0191
# Processing HTML file for CELEX 52003PC0147
# Processing HTML file for CELEX 52003PC0145
# Processing HTML file for CELEX 52003PC0117
# Processing HTML file for CELEX 52003PC0109
# Processing HTML file for CELEX 52003PC0094
# Processing HTML file for CELEX 52003PC0103
# Processing HTML file for CELEX 52003PC0092
# Processing HTML file for CELEX 52003PC0078(02)
# Processing HTML file for CELEX 52003PC0067
# Processing HTML file for CELEX 52003PC0046
# Processing HTML file for CELEX 52003PC0077
# Processing HTML file for CELEX 52003PC0063
# Processing HTML file for CELEX 52003PC0051
# Processing HTML file for CELEX 52003PC0044
# Processing HTML file for CELEX 52003PC0052
# Processing HTML file for CELEX 52003PC0050
# Processing HTML file for CELEX 52003PC0054
# Processing HTML file for CELEX 52003PC0001
# Processing HTML file for CELEX 52002PC0759
# Processing HTML file for CELEX 52002PC0765
# Processing HTML file for CELEX 52002PC0769
# Processing HTML file for CELEX 52002PC0750
# Processing HTML file for CELEX 52002PC0780
# Processing HTML file for CELEX 52002PC0751
# Processing HTML file for CELEX 52002PC0662
# Processing HTML file for CELEX 52002PC0625
# Processing HTML file for CELEX 52002PC0595
# Processing HTML file for CELEX 52002PC0642
# Processing HTML file for CELEX 52002PC0584
# Processing HTML file for CELEX 52002PC0581
# Processing HTML file for CELEX 52002PC0534
# Processing HTML file for CELEX 52002PC0529
# Processing HTML file for CELEX 52002PC0530
# Processing HTML file for CELEX 52002PC0488(01)
# Processing HTML file for CELEX 52002PC0494
# Processing HTML file for CELEX 52002PC0443
# Processing HTML file for CELEX 52002PC0485
# Processing HTML file for CELEX 52002PC0474
# Processing HTML file for CELEX 52002PC0459
# Processing HTML file for CELEX 52002PC0451
# Processing HTML file for CELEX 52002PC0425
# Processing HTML file for CELEX 52002PC0406(15)
# Processing HTML file for CELEX 52002PC0406(16)
# Processing HTML file for CELEX 52002PC0406(13)
# Processing HTML file for CELEX 52002PC0406(03)
# Processing HTML file for CELEX 52002PC0415
# Processing HTML file for CELEX 52002PC0340
# Processing HTML file for CELEX 52002PC0109
# Processing HTML file for CELEX 52002PC0401
# Processing HTML file for CELEX 52002PC0396
# Processing HTML file for CELEX 52002PC0375
# Processing HTML file for CELEX 52002PC0400
# Processing HTML file for CELEX 52002PC0404
# Processing HTML file for CELEX 52002PC0377
# Processing HTML file for CELEX 52002PC0328
# Processing HTML file for CELEX 52002PC0207
# Processing PDF file for CELEX 52002PC0336
# Processing HTML file for CELEX 52002PC0319
# Processing HTML file for CELEX 52002PC0244
# Processing HTML file for CELEX 52002PC0279
# Processing HTML file for CELEX 52002PC0259
# Processing HTML file for CELEX 52002PC0234
# Processing HTML file for CELEX 52002PC0226
# Processing HTML file for CELEX 52001PC0729
# Processing HTML file for CELEX 52002PC0193
# Processing HTML file for CELEX 52002PC0162
# Processing HTML file for CELEX 52002PC0159
# Processing HTML file for CELEX 52002PC0160
# Processing HTML file for CELEX 52002PC0158(02)
# Processing HTML file for CELEX 52002PC0158(01)
# Processing HTML file for CELEX 52002PC0152
# Processing HTML file for CELEX 52002PC0110
# Processing HTML file for CELEX 52002PC0153
# Processing HTML file for CELEX 52002PC0149
# Processing HTML file for CELEX 52002PC0120
# Processing PDF file for CELEX 52001PC0775
# Processing HTML file for CELEX 52002PC0119
# Processing HTML file for CELEX 52002PC0025
# Processing HTML file for CELEX 52002PC0017
# Processing HTML file for CELEX 52002PC0085
# Processing HTML file for CELEX 52002PC0092
# Processing HTML file for CELEX 52002PC0070
# Processing HTML file for CELEX 52002PC0023
# Processing HTML file for CELEX 52002PC0022
# Processing HTML file for CELEX 52002PC0021
# Processing HTML file for CELEX 52002PC0080
# Processing HTML file for CELEX 52002PC0054
# Processing HTML file for CELEX 52002PC0006
# Processing HTML file for CELEX 52002PC0026
# Processing HTML file for CELEX 52002PC0008
# Processing HTML file for CELEX 52001PC0803
# Processing HTML file for CELEX 52002PC0010
# Processing HTML file for CELEX 52002PC0001
# Processing HTML file for CELEX 52002PC0007
# Processing HTML file for CELEX 52001PC0807
# Processing HTML file for CELEX 52001PC0811
# Processing HTML file for CELEX 52001PC0074
# Processing HTML file for CELEX 52001PC0789(02)
# Processing HTML file for CELEX 52001PC0784
# Processing HTML file for CELEX 52001PC0547(01)
# Processing HTML file for CELEX 52001PC0546
# Processing HTML file for CELEX 52001PC0754
# Processing HTML file for CELEX 52001PC0742
# Processing HTML file for CELEX 52001PC0123
# Processing HTML file for CELEX 52001PC0624
# Processing PDF file for CELEX 52001PC0695
# Processing HTML file for CELEX 52001PC0545
# Processing HTML file for CELEX 52001PC0683
# Processing HTML file for CELEX 52001PC0404(02)
# Processing HTML file for CELEX 52001PC0404(01)
# Processing HTML file for CELEX 52001PC0404(03)
# Processing HTML file for CELEX 52001PC0466
# Processing HTML file for CELEX 52001PC0703
# Processing HTML file for CELEX 52001PC0581
# Processing HTML file for CELEX 52001PC0544
# Processing HTML file for CELEX 52001PC0612
# Processing HTML file for CELEX 52001PC0634(02)
# Processing HTML file for CELEX 52001PC0634(01)
# Processing HTML file for CELEX 52001PC0576
# Processing HTML file for CELEX 52001PC0543
# Processing HTML file for CELEX 52001PC0564(02)
# Processing HTML file for CELEX 52001PC0564(03)
# Processing HTML file for CELEX 52001PC0564(01)
# Processing HTML file for CELEX 52001PC0575
# Processing HTML file for CELEX 52001PC0584
# Processing HTML file for CELEX 52001PC0573
# Processing HTML file for CELEX 52001PC0533
# Processing HTML file for CELEX 52001PC0507(01)
# Processing HTML file for CELEX 52001PC0507(02)
# Processing HTML file for CELEX 52001PC0508
# Processing HTML file for CELEX 52001PC0500
# Processing HTML file for CELEX 52001PC0433
# Processing HTML file for CELEX 52001PC0490
# Processing HTML file for CELEX 52001PC0480
# Processing HTML file for CELEX 52001PC0182
# Processing HTML file for CELEX 52001PC0439
# Processing HTML file for CELEX 52001PC0449
# Processing HTML file for CELEX 52001PC0452(01)
# Processing HTML file for CELEX 52001PC0459
# Processing HTML file for CELEX 52001PC0452(02)
# Processing HTML file for CELEX 52001PC0407
# Processing HTML file for CELEX 52001PC0425
# Processing HTML file for CELEX 52001PC0418
# Processing HTML file for CELEX 52001PC0334
# Processing HTML file for CELEX 52001PC0417
# Processing HTML file for CELEX 52001PC0337
# Processing HTML file for CELEX 52001PC0335
# Processing HTML file for CELEX 52001PC0257
# Processing HTML file for CELEX 52001PC0344
# Processing HTML file for CELEX 52001PC0280
# Processing HTML file for CELEX 52001PC0281
# Processing HTML file for CELEX 52001PC0318
# Processing HTML file for CELEX 52001PC0283
# Processing HTML file for CELEX 52001PC0319
# Processing HTML file for CELEX 52001PC0272
# Processing HTML file for CELEX 52001PC0226
# Processing HTML file for CELEX 52001PC0256
# Processing HTML file for CELEX 52001PC0094(01)
# Processing HTML file for CELEX 52001PC0241
# Processing HTML file for CELEX 52001PC0125(02)
# Processing HTML file for CELEX 52001PC0125(01)
# Processing HTML file for CELEX 52001PC0213
# Processing PDF file for CELEX 52000PC0751
# Processing HTML file for CELEX 52001PC0139
# Processing HTML file for CELEX 52001PC0168
# Processing HTML file for CELEX 52001PC0149
# Processing HTML file for CELEX 52000PC0816
# Processing HTML file for CELEX 52000PC0899
# Processing HTML file for CELEX 52001PC0035
# Processing HTML file for CELEX 52001PC0083
# Processing HTML file for CELEX 52001PC0056
# Processing HTML file for CELEX 52001PC0100
# Processing HTML file for CELEX 52001PC0031
# Processing HTML file for CELEX 52000PC0898
# Processing HTML file for CELEX 52000PC0798
# Processing HTML file for CELEX 52001PC0080
# Processing HTML file for CELEX 52001PC0046
# Processing HTML file for CELEX 52001PC0038
# Processing HTML file for CELEX 52001PC0012
# Processing HTML file for CELEX 52001PC0001
# Processing HTML file for CELEX 52000PC0839
# Processing HTML file for CELEX 52000PC0832
# Processing HTML file for CELEX 52000PC0844
# Processing HTML file for CELEX 52000PC0862
# Processing HTML file for CELEX 52000PC0847
# Processing HTML file for CELEX 52000PC0831
# Processing HTML file for CELEX 52000PC0840
# Processing HTML file for CELEX 52000PC0815
# Processing HTML file for CELEX 52000PC0827
# Processing HTML file for CELEX 52000PC0802(03)
# Processing HTML file for CELEX 52000PC0802(02)
# Processing HTML file for CELEX 52000PC0802(01)
# Processing HTML file for CELEX 52000PC0595
# Processing HTML file for CELEX 52000PC0716
# Processing HTML file for CELEX 52000PC0617
# Processing HTML file for CELEX 52000PC0753
# Processing HTML file for CELEX 52000PC0507
# Processing HTML file for CELEX 52000PC0723
# Processing HTML file for CELEX 52000PC0574
# Processing HTML file for CELEX 52000PC0634
# Processing HTML file for CELEX 52000PC0573
# Processing HTML file for CELEX 52000PC0639
# Processing HTML file for CELEX 52000PC0529
# Processing HTML file for CELEX 52000PC0511
# Processing HTML file for CELEX 52000PC0566
# Processing HTML file for CELEX 52000SC1276
# Processing HTML file for CELEX 52000PC0583
# Processing HTML file for CELEX 52000PC0007
# Processing HTML file for CELEX 52000PC0568
# Processing HTML file for CELEX 52000PC0489(02)
# Processing HTML file for CELEX 52000PC0489(01)
# Processing HTML file for CELEX 52000PC0545
# Processing HTML file for CELEX 52000PC0407
# Processing HTML file for CELEX 52000PC0487
# Processing HTML file for CELEX 52000PC0385
# Processing HTML file for CELEX 52000PC0384
# Processing HTML file for CELEX 52000PC0392
# Processing HTML file for CELEX 52000PC0386
# Processing HTML file for CELEX 52000PC0394
# Processing HTML file for CELEX 52000PC0393
# Processing HTML file for CELEX 52000PC0523
# Processing HTML file for CELEX 52000PC0347(01)
# Processing HTML file for CELEX 52000PC0005
# Processing HTML file for CELEX 52000PC0468
# Processing HTML file for CELEX 52000PC0347(02)
# Processing HTML file for CELEX 52000PC0458
# Processing HTML file for CELEX 52000PC0126
# Processing HTML file for CELEX 52000PC0448
# Processing HTML file for CELEX 52000PC0438(03)
# Processing HTML file for CELEX 52000PC0438(05)
# Processing HTML file for CELEX 52000PC0438(02)
# Processing HTML file for CELEX 52000PC0459
# Processing HTML file for CELEX 52000PC0438(01)
# Processing HTML file for CELEX 52000PC0319
# Processing HTML file for CELEX 52000PC0275
# Processing HTML file for CELEX 52000PC0334
# Processing HTML file for CELEX 52000PC0276
# Processing HTML file for CELEX 52000PC0402
# Processing HTML file for CELEX 52000PC0427
# Processing HTML file for CELEX 52000PC0426
# Processing HTML file for CELEX 52000PC0320
# Processing HTML file for CELEX 52000SC1148
# Processing HTML file for CELEX 52000PC0398
# WARNING:root:Failed to process CELEX 52000PC0313 due to No valid format found
# Processing HTML file for CELEX 52000PC0302
# Processing HTML file for CELEX 52000PC0260
# Processing HTML file for CELEX 52000PC0314
# Processing HTML file for CELEX 52000PC0285
# Processing HTML file for CELEX 52000PC0368
# Processing HTML file for CELEX 52000PC0338
# Processing HTML file for CELEX 52000PC0340
# Processing HTML file for CELEX 52000PC0279
# Processing HTML file for CELEX 52000PC0179
# Processing HTML file for CELEX 52000PC0222
# Processing HTML file for CELEX 52000PC0186
# Processing HTML file for CELEX 52000PC0139
# Processing HTML file for CELEX 52000PC0189
# Processing HTML file for CELEX 52000PC0121
# Processing HTML file for CELEX 52000PC0142(01)
# Processing HTML file for CELEX 52000PC0137
# Processing HTML file for CELEX 52000PC0162
# Processing HTML file for CELEX 52000PC0142(03)
# Processing HTML file for CELEX 52000PC0142(02)
# Processing HTML file for CELEX 52000PC0080
# Processing HTML file for CELEX 52000PC0106
# Processing HTML file for CELEX 52000PC0096(02)
# Processing HTML file for CELEX 52000PC0030
# Processing HTML file for CELEX 52000PC0042
# Processing HTML file for CELEX 52000PC0047
# Processing HTML file for CELEX 52000PC0018
# Elapsed time: 6.0 minutes and 59.30 seconds
